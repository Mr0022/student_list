# %%
# Populate initial data
initial_data = [
    (140313141001, "mehran", "mehrani", "tehran", 20),
    (140313141002, "asghar", "asghari", "mashhad", 19),
    (140313141003, "hooshang", "hoshangi", "tabriz", 18),
    (140313141005, "sara", "saraii", "shiraz", 17),
    (140313141006, "javad", "javadi", "qom", 16)
]

# %%
import pandas as pd

# Define column names
columns = ["student_id", "firstname", "lastname", "city", "score"]

# Create DataFrame
df = pd.DataFrame(initial_data, columns=columns)

# Save DataFrame to CSV
df.to_csv('initial_data.csv', index=False)

print("Data saved to initial_data.csv")
# Out:
# Data saved to initial_data.csv

# %%
import pandas as pd

class ListNode:
    def __init__(self, student_id, firstname, lastname, city, score):
        self.student_id = student_id
        self.firstname = firstname
        self.lastname = lastname
        self.city = city
        self.score = score
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def add_student(self, student_id, firstname, lastname, city, score):
        new_node = ListNode(student_id, firstname, lastname, city, score)
        new_node.next = self.head
        self.head = new_node

    def delete_student(self, student_id):
        current = self.head
        prev = None
        while current and current.student_id != student_id:
            prev = current
            current = current.next
        if prev is None:
            self.head = current.next
        elif current:
            prev.next = current.next

    def edit_student(self, student_id, firstname=None, lastname=None, city=None, score=None):
        current = self.head
        while current:
            if current.student_id == student_id:
                if firstname:
                    current.firstname = firstname
                if lastname:
                    current.lastname = lastname
                if city:
                    current.city = city
                if score is not None:
                    current.score = score
                return
            current = current.next

    def to_dataframe(self):
        data = {
            "student_id": [],
            "firstname": [],
            "lastname": [],
            "city": [],
            "score": []
        }
        current = self.head
        while current:
            data["student_id"].append(current.student_id)
            data["firstname"].append(current.firstname)
            data["lastname"].append(current.lastname)
            data["city"].append(current.city)
            data["score"].append(current.score)
            current = current.next
        return pd.DataFrame(data)




def validate_input_Id(prompt, condition=lambda x: True, error_msg="Invalid input"):
    while True:
        try:
            value = int(input(prompt))
            if condition(value):
                return value
            else:
                print(error_msg)
        except ValueError:
            print(error_msg)

def validate_input_score(prompt, condition=lambda x: True, error_msg="Invalid input"):
    while True:
        try:
            user_input = input(prompt)
            if user_input == "":
                return None
            value = int(user_input)
            if condition(value):
                return value
            else:
                print(error_msg)
        except ValueError:
            print(error_msg)

def validate_input_char(prompt, error_msg="Invalid input"):
    while True:
        user_input = input(prompt)
        if user_input == "":
            return None
        if len(user_input) > 2:
            return user_input
        else:
            print(error_msg)

students = LinkedList()


df = pd.read_csv('initial_data.csv')


# Iterate through the DataFrame and add each row to the linked list
for _, row in df.iterrows():
    students.add_student(row['student_id'], row['firstname'], row['lastname'], row['city'], row['score'])





def add_student():
    Student_Id = validate_input_Id("Enter new student ID: ", lambda x: True, "Invalid student ID.")
    firstname = validate_input_char("Enter First Name: ", "At least 3 characters are necessary")
    lastname = validate_input_char("Enter Last Name: ", "At least 3 characters are necessary")
    city = validate_input_char("Enter City: ", "At least 3 characters are necessary")
    score = validate_input_score("Enter Score: ", lambda x: 0 <= x <= 20, "Score must be between 0 and 20.")
    students.add_student(Student_Id, firstname, lastname, city, score)
    return "Student added successfully."

def delete_student():
    Student_Id = validate_input_Id("Enter student ID to delete: ", lambda x: True, "Invalid student ID.")
    students.delete_student(Student_Id)
    return "Student deleted successfully."

def edit_student():
    Student_Id = validate_input_Id("Enter student ID to edit: ", lambda x: True, "Invalid student ID.")
    firstname = validate_input_char("Enter First Name (leave blank to keep current): ")
    lastname = validate_input_char("Enter Last Name (leave blank to keep current): ")
    city = validate_input_char("Enter City (leave blank to keep current): ")
    score = validate_input_score("Enter Score (leave blank to keep current): ", lambda x: x is None or 0 <= x <= 20, "Score must be between 0 and 20.")
    students.edit_student(Student_Id, firstname, lastname, city, score)
    return "Student updated successfully."

def show_data():
    df = students.to_dataframe()
    print(df.to_string(index=False))

# Save data to CSV file
def save_data():
    df = students.to_dataframe()
    df.to_csv('data.csv', index=False)


# Interactive menu
def menu():
    while True:
        print("\nMenu")
        print("1. Add New Student")
        print("2. Delete Existing Student")
        print("3. Edit Student Specification")
        print("4. Show Data")
        print("5. Exit")
        choice = input("Just enter the number from the list: ")
        if choice == '1':
            print(add_student())
        elif choice == '2':
            print(delete_student())
        elif choice == '3':
            print(edit_student())
        elif choice == '4':
            show_data()
        elif choice == '5':
            save_data()
            break
        else:
            print("Invalid choice. Please enter a number between 1 and 5.")

# Run the menu
menu()
# Out:
# Menu
# 1. Add New Student
# 2. Delete Existing Student
# 3. Edit Student Specification
# 4. Show Data
# 5. Exit
#   student_id firstname lastname    city  score
# 140313141006     javad   javadi     qom     16
# 140313141005      sara   saraii  shiraz     17
# 140313141003  hooshang hoshangi  tabriz     18
# 140313141002    asghar  asghari mashhad     19
# 140313141001    mehran  mehrani  tehran     20
#
# Menu
# 1. Add New Student
# 2. Delete Existing Student
# 3. Edit Student Specification
# 4. Show Data
# 5. Exit
